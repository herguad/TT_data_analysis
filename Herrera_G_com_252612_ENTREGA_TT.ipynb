# %% [markdown]
# # Entrega Final

# %% [markdown]
# Entorno y carga de datos

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.listdir("/content/drive/MyDrive/IT/py/Data Analysis/TalentoTech/Herrera Guadalupe - Com 25262 - TPI Data Analytics/datasets")
# Out:
# ['ventas.csv',
#  'clientes.csv',
#  'ventas.xlsx',
#  'marketing.csv',
#  'clientes_clean.csv',
#  'ventas_clean.csv',
#  'marketing_clean.csv']

# %%
ruta_clientes = "/content/drive/MyDrive/IT/py/Data Analysis/TalentoTech/Herrera Guadalupe - Com 25262 - TPI Data Analytics/datasets/clientes.csv"
ruta_marketing = "/content/drive/MyDrive/IT/py/Data Analysis/TalentoTech/Herrera Guadalupe - Com 25262 - TPI Data Analytics/datasets/marketing.csv"
ruta_ventas = "/content/drive/MyDrive/IT/py/Data Analysis/TalentoTech/Herrera Guadalupe - Com 25262 - TPI Data Analytics/datasets/ventas.csv"

ventas = pd.read_csv(ruta_ventas)
clientes = pd.read_csv(ruta_clientes)
marketing = pd.read_csv(ruta_marketing)

print("ventas.shape ->", ventas.shape)
print("clientes.shape ->", clientes.shape)
print("marketing.shape ->", marketing.shape)

display(ventas.head(3))
display(clientes.head(3))
display(marketing.head(3))
# Out:
# ventas.shape -> (3035, 6)
# clientes.shape -> (567, 5)
# marketing.shape -> (90, 6)
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      Aloysia Screase    44  Mar del Plata  42294.68
# 1           2  Kristina Scaplehorn    25        Posadas  24735.04
# 2           3       Filip Castagne    50    Resistencia  35744.85
#    id_campanha         producto  canal  costo fecha_inicio   fecha_fin
# 0           74  Adorno de pared     TV   4.81   20/03/2024  03/05/2024
# 1           12           Tablet   RRSS   3.40   26/03/2024  13/05/2024
# ...

# %% [markdown]
# ## 1.4 Exploración de datos (inicial)

# %%
def eda(df, nombre):
    print(f"=== {nombre} ===")
    print("shape:", df.shape)
    print("columnas:", list(df.columns))
    print("dtypes:")
    print(df.dtypes)
    print("\nNulos por columna:")
    print(df.isna().sum())
    print("\nPrimeras filas:")
    display(df.head(5))
    print("\nDescribe (numérico):")
    display(df.describe(include='number'))
    print("-"*100)

# %%
eda(ventas, "Ventas (inicial)")
# Out:
# === Ventas (inicial) ===
# shape: (3035, 6)
# columnas: ['id_venta', 'producto', 'precio', 'cantidad', 'fecha_venta', 'categoria']
# dtypes:
# id_venta         int64
# producto        object
# precio          object
# cantidad       float64
# fecha_venta     object
# categoria       object
# dtype: object
#
# Nulos por columna:
# id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64
#
# Primeras filas:
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
# 3      1372           Heladera  $114.35       8.0  02/01/2024
# 4      1546           Secadora  $106.21       4.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# ...

# %%
eda(clientes, "Clientes (inicial)")
# Out:
# === Clientes (inicial) ===
# shape: (567, 5)
# columnas: ['id_cliente', 'nombre', 'edad', 'ciudad', 'ingresos']
# dtypes:
# id_cliente      int64
# nombre         object
# edad            int64
# ciudad         object
# ingresos      float64
# dtype: object
#
# Nulos por columna:
# id_cliente    0
# nombre        0
# edad          0
# ciudad        0
# ingresos      0
# dtype: int64
#
# Primeras filas:
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      Aloysia Screase    44  Mar del Plata  42294.68
# 1           2  Kristina Scaplehorn    25        Posadas  24735.04
# 2           3       Filip Castagne    50    Resistencia  35744.85
# 3           4          Liuka Luard    39   Bahía Blanca  27647.96
# 4           5        Dore Cockshtt    28        Rosario  28245.65
# Describe (numérico):
#        id_cliente        edad      ingresos
# count  567.000000  567.000000    567.000000
# mean   284.000000   37.940035  34668.739012
# ...

# %%
eda(marketing, "Marketing (inicial)")
# Out:
# === Marketing (inicial) ===
# shape: (90, 6)
# columnas: ['id_campanha', 'producto', 'canal', 'costo', 'fecha_inicio', 'fecha_fin']
# dtypes:
# id_campanha       int64
# producto         object
# canal            object
# costo           float64
# fecha_inicio     object
# fecha_fin        object
# dtype: object
#
# Nulos por columna:
# id_campanha     0
# producto        0
# canal           0
# costo           0
# fecha_inicio    0
# fecha_fin       0
# dtype: int64
#
# Primeras filas:
#    id_campanha         producto  canal  costo fecha_inicio   fecha_fin
# 0           74  Adorno de pared     TV   4.81   20/03/2024  03/05/2024
# 1           12           Tablet   RRSS   3.40   26/03/2024  13/05/2024
# 2           32  Lámpara de mesa  Email   5.54   28/03/2024  20/04/2024
# 3           21       Smartphone   RRSS   6.37   29/03/2024  16/05/2024
# 4           58         Alfombra  Email   4.25   31/03/2024  05/05/2024
# Describe (numérico):
#        id_campanha      costo
# ...

# %% [markdown]
# ## 1.5 Calidad de datos (nulos y duplicados)

# %%
# ============================================
# FUNCIÓN DE CONTROL DE CALIDAD DE DATOS
# ============================================
# Esta función analiza un DataFrame existente (df) y muestra:
# 1️. La cantidad de valores nulos por columna.
# 2️. El total de filas completamente duplicadas.
# 3️. Si se especifica una columna clave, muestra los valores más repetidos de esa columna.

def calidad(df,nombre, clave=None):
  print(f"# {nombre}")
  display(df.isna().sum().to_frame("nulos"))
  dup_filas = df.duplicated(keep=False).sum()
  print("Filas duplicadas: ",dup_filas)
  if clave and clave in df.columns:
    dup_key=df[clave].duplicated(keep=False).sum()
    print(f"Duplicados por columna '{clave}': ", dup_key)
    if dup_key > 0:
      duplicados_ord = (
          df[df[clave].duplicated(keep=False)][clave]
                .value_counts()
                .sort_values(ascending=False)
                )

      print("\n Top 10 valores duplicados más frecuentes: ")
      display(duplicados_ord.head(10))
    else:
      print(f"No se encontraron duplicados en la clave '{clave}'.")
  else:
      if clave:
         print(f"La clave '{clave}' no existe en la DataFrame.")

      else:
        print("No se indicó una clave para analizar duplicados por columna.")

# %%
calidad(ventas,"Ventas", clave="id_venta")
# Out:
# # Ventas
#              nulos
# id_venta         0
# producto         0
# precio           2
# cantidad         2
# fecha_venta      0
# categoria        0
# Filas duplicadas:  70
# Duplicados por columna 'id_venta':  70
#
#  Top 10 valores duplicados más frecuentes:
# id_venta
# 56      2
# 421     2
# 424     2
# 1868    2
# 2545    2
# 2778    2
# 145     2
# 300     2
# 439     2
# 906     2
# Name: count, dtype: int64

# %%
calidad(clientes,"Clientes",clave="id_cliente")
# Out:
# # Clientes
#             nulos
# id_cliente      0
# nombre          0
# edad            0
# ciudad          0
# ingresos        0
# Filas duplicadas:  0
# Duplicados por columna 'id_cliente':  0
# No se encontraron duplicados en la clave 'id_cliente'.

# %%
calidad(marketing,"Marketing",clave="id_campanha")
# Out:
# # Marketing
#               nulos
# id_campanha       0
# producto          0
# canal             0
# costo             0
# fecha_inicio      0
# fecha_fin         0
# Filas duplicadas:  0
# Duplicados por columna 'id_campanha':  0
# No se encontraron duplicados en la clave 'id_campanha'.

# %% [markdown]
# ## 2.1 Limpieza de Datos
# - Eliminación de duplicados
# - Normalización de texto en columnas de tipo `object`
# - Conversión de fechas a formato datetime (estándar)
# - Conversión de `precio` y `cantidad` (df 'Ventas') a tipo numérico.
# - Guardado de csv limpios.

# %%
# ============================================
# LIMPIEZA Y NORMALIZACIÓN DE LOS DATASETS
# ============================================

# 1️. Crear copias independientes para no modificar los originales

ventas_clean = ventas.copy()
clientes_clean = clientes.copy()
marketing_clean = marketing.copy()

# 2️. Eliminar filas completamente duplicadas

ventas_clean = ventas_clean.drop_duplicates()
clientes_clean = clientes_clean.drop_duplicates()
marketing_clean = marketing_clean.drop_duplicates()

# %%
# 3. Verificar que las dfs correspondientes quedaron limpias.
calidad(ventas_clean,"Ventas (Limpio)", clave="id_venta")
# Out:
# # Ventas (Limpio)
#              nulos
# id_venta         0
# producto         0
# precio           2
# cantidad         2
# fecha_venta      0
# categoria        0
# Filas duplicadas:  0
# Duplicados por columna 'id_venta':  0
# No se encontraron duplicados en la clave 'id_venta'.

# %%
# 4. Normalización de texto en columnas de tipo string
def norm_texto(df):
  for col in df.select_dtypes(include="object").columns:
    df[col] = (
       df[col].astype(str)
       .str.strip()
       .str.replace(r"[\u200b\t\r\n]", "", regex=True)
       .str.replace(" +", " ", regex=True)
       .str.title()
    )
  return df

# %%
# Aplicar la función para normalizar el texto en las dfs limpias
ventas_clean = norm_texto(ventas_clean)
clientes_clean = norm_texto(clientes_clean)
marketing_clean = norm_texto(marketing_clean)

# %%
# 5. Normalizar fechas
for df in [ventas_clean, clientes_clean, marketing_clean]:
    for col in df.columns:
        if "fecha" in col.lower():  # detecta columnas con la palabra "fecha"
            df[col] = pd.to_datetime(df[col], errors="coerce", dayfirst=True)

# %%
# Verificar que la normalización de fechas y texto se aplicó
#-----Revisar tipos------
print(ventas_clean.dtypes)
print(clientes_clean.dtypes)
print(marketing_clean.dtypes)

#------Revisar texto------
print(ventas_clean.head(10))
print(clientes_clean.head(10))
print(marketing_clean.head(10))
# Out:
# id_venta                int64
# producto               object
# precio                 object
# cantidad              float64
# fecha_venta    datetime64[ns]
# categoria              object
# dtype: object
# id_cliente      int64
# nombre         object
# edad            int64
# ciudad         object
# ingresos      float64
# dtype: object
# id_campanha              int64
# producto                object
# canal                   object
# costo                  float64
# fecha_inicio    datetime64[ns]
# fecha_fin       datetime64[ns]
# dtype: object
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro Decorativo   $69.94       5.0  2024-01-02
# 1       811    Lámpara De Mesa  $105.10       5.0  2024-01-02
# 2      1156           Secadora   $97.96       3.0  2024-01-02
# 3      1372           Heladera  $114.35       8.0  2024-01-02
# 4      1546           Secadora  $106.21       4.0  2024-01-02
# ...

# %%
# 6.1 Normalización de valores numéricos: Campo 'precio'
if "precio" in ventas_clean.columns:
    ventas_clean["precio"] = (
        ventas_clean["precio"]
        .astype(str)                        # Convierte todo a texto
        .str.replace("$", "", regex=False)  # Elimina el símbolo $
        .str.replace(",", "", regex=False)  # Elimina comas de miles
        .str.strip()                        # Quita espacios sobrantes
    )
    ventas_clean["precio"] = pd.to_numeric(ventas_clean["precio"], errors="coerce")

# %%
# Revisar normalización de columna 'precio'
print(ventas_clean.dtypes)
# Out:
# id_venta                int64
# producto               object
# precio                float64
# cantidad              float64
# fecha_venta    datetime64[ns]
# categoria              object
# dtype: object

# %%
# 6.2 Normalización de valores numéricos: Campo 'cantidad'
if "cantidad" in ventas_clean.columns:
    ventas_clean["cantidad"] = pd.to_numeric(ventas_clean["cantidad"], errors="coerce").astype("Int64")
    # .astype("Int64") usa el tipo entero de pandas que permite valores nulos (NaN)

# %%
# Revisar normalización de columna 'cantidad'
print(ventas_clean.dtypes)
# Out:
# id_venta                int64
# producto               object
# precio                float64
# cantidad                Int64
# fecha_venta    datetime64[ns]
# categoria              object
# dtype: object

# %%
# 8. Guardado de dfs limpios como .csv
ventas_clean.to_csv("/content/drive/MyDrive/IT/py/Data Analysis/TalentoTech/Herrera Guadalupe - Com 25262 - TPI Data Analytics/datasets/ventas_clean.csv", index=False)
clientes_clean.to_csv("/content/drive/MyDrive/IT/py/Data Analysis/TalentoTech/Herrera Guadalupe - Com 25262 - TPI Data Analytics/datasets/clientes_clean.csv", index=False)
marketing_clean.to_csv("/content/drive/MyDrive/IT/py/Data Analysis/TalentoTech/Herrera Guadalupe - Com 25262 - TPI Data Analytics/datasets/marketing_clean.csv", index=False)

print("Archivos guardados: ventas_clean.csv, clientes_clean.csv, marketing_clean.csv")

# Ver información básica de las dfs actualizadas:
ventas_clean.info()
clientes_clean.info()
marketing_clean.info()
# Out:
# Archivos guardados: ventas_clean.csv, clientes_clean.csv, marketing_clean.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, 0 to 3034
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     3000 non-null   int64
#  1   producto     3000 non-null   object
#  2   precio       2998 non-null   float64
#  3   cantidad     2998 non-null   Int64
#  4   fecha_venta  3000 non-null   datetime64[ns]
#  5   categoria    3000 non-null   object
# dtypes: Int64(1), datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 167.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_cliente  567 non-null    int64
#  1   nombre      567 non-null    object
#  2   edad        567 non-null    int64
#  3   ciudad      567 non-null    object
# ...

# %% [markdown]
# ## Reporte post- limpieza de datos

# %%
# ============================================
# REPORTE GLOBAL DE CALIDAD DE DATOS
# ============================================
# Esta función lee los dfs limpios
# y muestra un resumen comparativo de nulos, duplicados y tipos.
# ============================================

def reporte_calidad_global(dfs,nombres):
  resumen=[]
  for df,nombre in zip(dfs,nombres):
                       nulos = df.isna().sum().sum() #suma los nulos de todas las columnas
                       duplicados = df.duplicated(keep=False).sum()
                       columnas = len(df.columns)
                       filas = len(df)

                       resumen.append({
                           "Dataset": nombre,
                           "Filas": filas,
                           "Columnas": columnas,
                           "Total nulos": nulos,
                           "Total filas duplicadas": duplicados,
                       })

  reporte = pd.DataFrame(resumen)
  return reporte

# %%
# Aplicar función "reporte_calidad_global" a las dfs originales y luego a las limpias para comparar
reporte_originales= reporte_calidad_global([ventas, clientes, marketing], ["Ventas Original", "Clientes Original", "Marketing Original"])
reporte_limpias= reporte_calidad_global([ventas_clean, clientes_clean, marketing_clean],["Ventas Limpio", "Clientes Limpio", "Marketing Limpio"])

print(reporte_originales)

print(reporte_limpias)
# Out:
#               Dataset  Filas  Columnas  Total nulos  Total filas duplicadas
# 0     Ventas Original   3035         6            4                      70
# 1   Clientes Original    567         5            0                       0
# 2  Marketing Original     90         6            0                       0
#             Dataset  Filas  Columnas  Total nulos  Total filas duplicadas
# 0     Ventas Limpio   3000         6            4                       0
# 1   Clientes Limpio    567         5            0                       0
# 2  Marketing Limpio     90         6            0                       0

# %% [markdown]
# ## 2.2 Transformación de Datos

# %%
## Transformación de Datos
# 1. Productos de alto rendimiento
# Objetivo:
# - Detectar los productos con mejor desempeño económico (top 20% por ingreso total).
# - Aplicar transformación: calcular ingreso, agregar por producto y filtrar.

# Definir función que busca la primera columna cuyo nombre contenga alguno de los patrones dados
# que devuelva el nombre original de la columna en ese caso
# o None si no encuentra coincidencias

def encontrar_columna(df, patrones):
    for c in df.columns:
        nombre = c.lower()
        if any(p in nombre for p in patrones):
            return c
    return None

# %%
# Detectar la columna de producto
prod_col = encontrar_columna(ventas_clean, ["producto", "id_producto", "sku", "articulo", "artículo"])
if prod_col is None:
    raise ValueError("No se encontró columna de producto. Renombrá una columna a 'producto' o similar.")
print(prod_col)
# Out:
# producto

# %%
# Calcular el ingreso por datapoint(registro) multiplicando precio por cantidad.
# Inlcuir resultado en una columna nueva.
# assign(**nuevas_col): crea nuevas columnas y devuelve una copia del df.

ventas_perform = (
    ventas_clean
    .assign(
        ingreso = ventas_clean["precio"] * ventas_clean["cantidad"]
    )
)

# %%
## Transformación de Datos
#2. Agregación: agrupar el df por una o varias columnas clave y resumir las columnas numéricas por cada grupo.
resumen_prod = (
    ventas_perform.groupby(by=prod_col,dropna=False, as_index=False, observed=False)
    .agg(
        ingreso_total=('ingreso', 'sum'),
        unidades=('cantidad', 'sum'),
        precio_promedio=('precio', 'mean'),
        registros=('ingreso', 'size')       # Número de filas en el grupo (cuenta TODO, incluso NaN).
    )
)

#Ver resumen
print(resumen_prod.head(20))
# Out:
#                   producto  ingreso_total  unidades  precio_promedio  \
# 0          Adorno De Pared       48093.49       633        76.097800
# 1                 Alfombra       44773.06       615        74.098300
# 2               Aspiradora       50085.86       651        77.447400
# 3              Auriculares       74175.58       958        76.302727
# 4                 Batidora        50979.2       672        77.537200
# 5                 Cafetera       59607.31       765        79.046581
# 6               Candelabro        11128.8       160        74.595417
# 7   Consola De Videojuegos       46174.41       623        76.346869
# 8                 Cortinas       44865.03       610        73.649900
# 9        Cuadro Decorativo        54297.6       726        74.578000
# 10          Cámara Digital       45217.96       638        72.010700
# 11   Elementos De Cerámica       45411.09       636        71.611515
# 12       Espejo Decorativo       46783.31       635        75.663300
# ...

# %%
# Ordenar resumen_prod por el mayor ingreso_total.
# Redondear precio_promedio a 2 decimales redondeado.
resumen_prod['precio_promedio']=round(resumen_prod['precio_promedio'],2)
resumen_sort=resumen_prod.sort_values(by='ingreso_total',ascending=False)

print(resumen_sort.head(10))
# Out:
#              producto  ingreso_total  unidades  precio_promedio  registros
# 19    Lámpara De Mesa       82276.38      1112            72.72        176
# 3         Auriculares       74175.58       958            76.30        143
# 20         Microondas       72562.89       912            79.18        135
# 5            Cafetera       59607.31       765            79.05        117
# 9   Cuadro Decorativo        54297.6       726            74.58        100
# 26         Smartphone       54132.44       665            81.40        101
# 25           Secadora       52115.45       696            73.34        100
# 16  Jarrón Decorativo       51130.88       672            74.53        100
# 4            Batidora        50979.2       672            77.54        100
# 24  Rincón De Plantas       50456.45       691            74.82        101

# %%
# Cálculo del 80% del ingreso total (quantile())
p80_ingreso = resumen_prod["ingreso_total"].quantile(q=0.80,interpolation="linear")

# print(80-ingreso) muestra el límite superior del 80% de los productos.
print(p80_ingreso)
# Out:
# 52518.848000000005

# %%
# A partir del valor obtenido como límite del 80% del ingreso,
# filtrar productos cuyo ingreso_total está en el 20% superior y
# ordenarlos de mayor a menor por ingreso y unidades.
# en una sola fila

top_ventas = (resumen_prod.query(
        "ingreso_total >= @p80_ingreso",
        engine="python" )
        .sort_values(
        by=["ingreso_total", "unidades"],
        ascending=[False, False],
        na_position="last",
        ignore_index=True
            )
        )

# Mostrar resultados
print(f"Columna de producto detectada: {prod_col}")
print(f"Umbral (percentil 80) de ingreso_total: {float(p80_ingreso):,.2f}")
print("---- Productos de ALTO RENDIMIENTO (top 20% por ingreso) ----")
display(top_ventas.head(20))
# Out:
# Columna de producto detectada: producto
# Umbral (percentil 80) de ingreso_total: 52,518.85
# ---- Productos de ALTO RENDIMIENTO (top 20% por ingreso) ----
#             producto  ingreso_total  unidades  precio_promedio  registros
# 0    Lámpara De Mesa       82276.38      1112            72.72        176
# 1        Auriculares       74175.58       958            76.30        143
# 2         Microondas       72562.89       912            79.18        135
# 3           Cafetera       59607.31       765            79.05        117
# 4  Cuadro Decorativo        54297.6       726            74.58        100
# 5         Smartphone       54132.44       665            81.40        101

# %% [markdown]
# ## 2.3 Agregación de datos
# ## Resumen de ventas por categoría de producto y análisis de ingresos generados.

# %%
## Transformación de datos
# Datasets:
#ventas : dataset original
#ventas_clean: dataset original despues de limpiar datos
#ventas_perform: dataset de ventas_clean con el campo ingreso que es precio*cantidad de cada factura
#resumen_prod: dataset de ventas_perf agrupado por producto y sumado el ingreso de cada venta (ingreso_total)
#top_ventas: el detaset de resumen_prod pero solo incluye los productos mas vendidos (top del 20%)
#ventas_cat: df copia de ventas_perform
#resumen_cat: sobre ventas_cat, agrupo por categoria de producto y sumo ingreso_total

ventas_cat = ventas_perform.copy()

resumen_cat = (ventas_cat.groupby(by='categoria', dropna=False,as_index=False)
             .agg(ingreso_total=('ingreso', 'sum'),
                  unidades=('cantidad', 'sum'),
                  ventas=('ingreso', 'size'),
                  precio_promedio=('precio', 'mean'))
             .sort_values(
                 by='ingreso_total',
                 ascending=False,
                 na_position='last',
                 ignore_index=True # Reindexar desde 0
             ))

# Nueva columna para incluir ticket promedio por venta.
resumen_cat = resumen_cat.assign(
    ticket_promedio_por_venta = resumen_cat['ingreso_total'] / resumen_cat['ventas'])

print("Resumen por categoría (ordenado por ingreso_total):")
display(resumen_cat.head(20))
# Out:
# Resumen por categoría (ordenado por ingreso_total):
#            categoria  ingreso_total  unidades  ventas  precio_promedio  \
# 0  Electrodomésticos      505299.63      6592    1000         76.52096
# 1        Electrónica       482577.8      6413     999         75.25492
# 2         Decoración      479216.09      6490    1001         74.09800
#
#    ticket_promedio_por_venta
# 0                  505.29963
# 1                 483.060861
# 2                 478.737353

# %% [markdown]
# ## 2.4 Integración de Datos

# %%
# Agrupar ventas_clean por producto y
# agregar una columna que muestre la cantidad por el precio.
ventas_producto = ventas_clean.groupby('producto').agg(
    precio_cantidad=('precio', lambda x: (x * ventas_clean.loc[x.index, 'cantidad']).sum()))

# Ordenar ascendente por producto (i.e. alfabéticamente)
ventas_producto = ventas_producto.sort_values(by='producto', ascending=True)

# Mostrar resultado
display(ventas_producto)
# Out:
#                         precio_cantidad
# producto
# Adorno De Pared                48093.49
# Alfombra                       44773.06
# Aspiradora                     50085.86
# Auriculares                    74175.58
# Batidora                       50979.20
# Cafetera                       59607.31
# Candelabro                     11128.80
# Consola De Videojuegos         46174.41
# Cortinas                       44865.03
# Cuadro Decorativo              54297.60
# Cámara Digital                 45217.96
# Elementos De Cerámica          45411.09
# Espejo Decorativo              46783.31
# Freidora Eléctrica             50155.15
# Heladera                       25736.80
# Horno Eléctrico                49913.90
# Jarrón Decorativo              51130.88
# Laptop                         46179.48
# Lavadora                       48946.44
# Lámpara De Mesa                82276.38
# Microondas                     72562.89
# Parlantes Bluetooth            47779.46
# ...

# %%
# Análisis de rendimiento de productos relevantes

# %%
# Agrupar marketing_clean por producto y sumar el costo de las campañas de ese producto

marketing_producto = marketing_clean.groupby('producto')['costo'].sum().reset_index()
marketing_producto = marketing_producto[['producto', 'costo']]
marketing_producto = marketing_producto.sort_values(by='producto', ascending=True)
display(marketing_producto)
# Out:
#                   producto  costo
# 0          Adorno De Pared  14.05
# 1                 Alfombra  17.46
# 2               Aspiradora  16.46
# 3              Auriculares  15.24
# 4                 Batidora  15.28
# 5                 Cafetera  18.16
# 6               Candelabro  14.65
# 7   Consola De Videojuegos  12.77
# 8                 Cortinas  17.36
# 9        Cuadro Decorativo  15.85
# 10          Cámara Digital  16.40
# 11   Elementos De Cerámica  16.87
# 12       Espejo Decorativo  14.89
# 13      Freidora Eléctrica  13.56
# 14                Heladera  13.11
# 15         Horno Eléctrico  13.89
# 16       Jarrón Decorativo  13.27
# 17                  Laptop  15.19
# 18                Lavadora  11.85
# 19         Lámpara De Mesa  15.93
# 20              Microondas  14.19
# 21     Parlantes Bluetooth  13.37
# 22        Plancha De Vapor  14.12
# 23               Proyector  12.47
# 24       Rincón De Plantas  16.45
# 25                Secadora  14.59
# ...

# %%
#Ensamble del dataset ventas por producto con el de marketing por producto agrupado por producto
merged_df = pd.merge(ventas_producto, marketing_producto, on='producto')
display(merged_df)
# Out:
#                   producto  precio_cantidad  costo
# 0          Adorno De Pared         48093.49  14.05
# 1                 Alfombra         44773.06  17.46
# 2               Aspiradora         50085.86  16.46
# 3              Auriculares         74175.58  15.24
# 4                 Batidora         50979.20  15.28
# 5                 Cafetera         59607.31  18.16
# 6               Candelabro         11128.80  14.65
# 7   Consola De Videojuegos         46174.41  12.77
# 8                 Cortinas         44865.03  17.36
# 9        Cuadro Decorativo         54297.60  15.85
# 10          Cámara Digital         45217.96  16.40
# 11   Elementos De Cerámica         45411.09  16.87
# 12       Espejo Decorativo         46783.31  14.89
# 13      Freidora Eléctrica         50155.15  13.56
# 14                Heladera         25736.80  13.11
# 15         Horno Eléctrico         49913.90  13.89
# 16       Jarrón Decorativo         51130.88  13.27
# ...

# %%
#Cálculo del % que representa el costo sobre el ingreso
merged_df['%_costo_ingreso'] = (merged_df['costo'] / merged_df['precio_cantidad'])*100
merged_df['%_costo_ingreso'] =round(merged_df['%_costo_ingreso'],4)
display(merged_df)
# Out:
#                   producto  precio_cantidad  costo  %_costo_ingreso
# 0          Adorno De Pared         48093.49  14.05           0.0292
# 1                 Alfombra         44773.06  17.46           0.0390
# 2               Aspiradora         50085.86  16.46           0.0329
# 3              Auriculares         74175.58  15.24           0.0205
# 4                 Batidora         50979.20  15.28           0.0300
# 5                 Cafetera         59607.31  18.16           0.0305
# 6               Candelabro         11128.80  14.65           0.1316
# 7   Consola De Videojuegos         46174.41  12.77           0.0277
# 8                 Cortinas         44865.03  17.36           0.0387
# 9        Cuadro Decorativo         54297.60  15.85           0.0292
# 10          Cámara Digital         45217.96  16.40           0.0363
# 11   Elementos De Cerámica         45411.09  16.87           0.0371
# 12       Espejo Decorativo         46783.31  14.89           0.0318
# ...

# %%
# Visualización inicial para identificar valores de dispersión y valores atípicos
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.boxplot(y=merged_df['%_costo_ingreso'], color='darkmagenta')
plt.title('Porcentaje de Costo sobre Ingreso')
plt.ylabel('Porcentaje de Costo sobre Ingreso')
plt.show()

# %%
# Ver distribución del % de costo sobre el ingreso en un histograma.

plt.figure(figsize=(8, 6))
sns.histplot(merged_df['%_costo_ingreso'], kde=True,color='darkmagenta')
plt.title('Distribución del Porcentaje de Costo sobre Ingreso')
plt.xlabel('Porcentaje de Costo sobre Ingreso')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ## 3.1 Estadística Descriptiva: Medidas de tendencia central y dispersión de las ventas

# %% [markdown]
# ## Resúmenes gráficos por categoría

# %%
# --------- Gráfico de barras que muestra el ingreso por categoría ---------
df2=resumen_cat.copy()

df_2 = df2.sort_values('ingreso_total',ascending=False)

plt.figure(figsize=(12,10))
color_indigo= "#49019f"
#palette: #006b6b (teal)  #9f0161 (magenta)  #ffc505 (yellow) #0a662c (green)  #49019f (indigo)
barras = plt.bar(df_2["categoria"], df_2["ingreso_total"], color=color_indigo)
plt.title("Ingresos Totales por Categoría", fontsize=14, weight="bold")
plt.xlabel("Categoría", fontsize=12)
plt.ylabel("Ingreso Total ($)", fontsize=12)

for barra in barras:
  y = barra.get_height()
  plt.text( barra.get_x() + barra.get_width() / 2, y / 2,
           f"${y:,.0f}",
            ha='center', va='center',
            fontsize=16, color="white"
            )
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Medidas de Tendencia Central

# %%
df1 =resumen_prod.copy()

media = df1['ingreso_total'].mean()
mediana = df1['ingreso_total'].median()
moda = df1['ingreso_total'].mode()

print("Media:", media)
print("Mediana:", mediana)
print("Moda:")
print(moda)
# Out:
# Media: 48903.117333333335
# Mediana: 48140.244999999995
# Moda:
# 0      11128.8
# 1      25736.8
# 2     25856.57
# 3     44773.06
# 4     44865.03
# 5     45196.63
# 6     45217.96
# 7     45411.09
# 8     46174.41
# 9     46179.48
# 10    46783.31
# 11    47038.04
# 12    47779.46
# 13    47836.86
# 14    48093.49
# 15     48187.0
# 16    48946.44
# 17     49913.9
# 18    50085.86
# 19    50155.15
# 20    50456.45
# 21     50979.2
# 22    51130.88
# 23    52115.45
# 24    54132.44
# 25     54297.6
# 26    59607.31
# 27    72562.89
# 28    74175.58
# 29    82276.38
# Name: ingreso_total, dtype: Float64

# %% [markdown]
# ## Medidas de Dispersión

# %%
# ------------ Dispersión del Ingreso Total ------------
rango_ingreso = df1['ingreso_total'].max() - df1['ingreso_total'].min()
varianza_ingreso = df1['ingreso_total'].var(ddof=1)
desviacion_ingreso = df1['ingreso_total'].std(ddof=1)


print("Rango del Ingreso Total: ", rango_ingreso)
print("Varianza del Ingreso Total: ", round(varianza_ingreso,3))
print("Desviación estándar del Ingreso Total: ", round(desviacion_ingreso,3))
# Out:
# Rango del Ingreso Total:  71147.58
# Varianza del Ingreso Total:  175975127.625
# Desviación estándar del Ingreso Total:  13265.562

# %%
# ------------ Dispersión del Precio Promedio ------------
rango_precio_prom = df1['precio_promedio'].max() - df1['precio_promedio'].min()
desviacion_precio_prom = df1['precio_promedio'].std(ddof=1)

print("Rango del Precio Promedio: ", round(rango_precio_prom,3))
print("Desviación estándar del Precio Promedio: ", round(desviacion_precio_prom,3))
# Out:
# Rango del Precio Promedio:  10.02
# Desviación estándar del Precio Promedio:  2.317

# %% [markdown]
# ### Comparación entre Promedio y Desviación Estándar de Ingresos Totales por Producto
#
# **Valores Obtenidos:**
# - **Media (Promedio):** 48,903.12
#
# - **Mediana:** 48,140.24
#
# - **Desviación Estándar:** 13,265.56
#
# - **Rango:** 71,147.58 (Máximo 82,276.38 - Mínimo 11,128.80)
#
# **Análisis:**
#
# 1.  **Media vs. Mediana:**
#
#     El promedio= 48,903.12 y la mediana= 48,140.24 son valores muy cercanos. Esto sugiere que la distribución de los ingresos totales por producto es relativamente simétrica, por lo cual no no influye en posibles sesgos sobre el promedio.
#
# 2.  **Desviación Estándar:**
#
#     La desviación estándar de 13,265.56 indica la dispersión promedio de los ingresos de cada producto con respecto a la media. En relación con la media de $48,903.12, esta desviación es considerable (aproximadamente un 27% de la media).
#
# 3.  **Rango:**
#     El rango de 71,147.58, que va desde el producto con menores ingresos (11,128.80) hasta el de mayores ingresos (82,276.38), confirma una amplia variabilidad entre los productos.
#
# **Conclusión**
#
#   Aunque el promedio y la mediana son similares, es decir, una distribución de ingresos relativamente equilibrada, la **alta desviación estándar** y el **amplio rango** de los ingresos totales por producto revelan una **variabilidad significativa**.
#
#   Esto significa que no todos los productos generan ingresos de manera uniforme. Existen productos con un rendimiento muy superior y otros con un rendimiento considerablemente inferior.
#
#   Esta heterogeneidad es importante para la toma de decisiones estratégicas, por ejemplo:
#   - la identificación de productos de alto rendimiento a potenciar o
#   - la idenfiticación de productos de bajo rendimiento que podrían requerir una reevaluación o campañas de marketing específicas.
#
#   La desviación estándar indica que, en promedio, los ingresos individuales de los productos se desvían considerablemente del ingreso promedio general.

# %% [markdown]
# ## Cálculo del rango intercuartílico (IQR)

# %%
q1 = df1['ingreso_total'].quantile(0.25)
q2 = df1['ingreso_total'].quantile(0.5)
q3 = df1['ingreso_total'].quantile(0.75)
iqr = q3 - q1

print("Q1:", round(q1,3))
print("Mediana (Q2):", round(q2,3))
print("Q3:", round(q3,3))
print("IQR:", round(iqr,3))
# Out:
# Q1: 45601.92
# Mediana (Q2): 48140.245
# Q3: 51092.96
# IQR: 5491.04

# %% [markdown]
# ## Detección de outliers usando el IQR

# %%
lim_inf = q1 - 1.5 * iqr
lim_sup = q3 + 1.5 * iqr

outliers = df1[(df1['ingreso_total'] < lim_inf) | (df1['ingreso_total'] > lim_sup)]

print("Límite inferior:", lim_inf)
print("Límite superior:", lim_sup)
print("\nOutliers detectados:")
print(outliers)
# Out:
# Límite inferior: 37365.36
# Límite superior: 59329.520000000004
#
# Outliers detectados:
#            producto  ingreso_total  unidades  precio_promedio  registros
# 3       Auriculares       74175.58       958            76.30        143
# 5          Cafetera       59607.31       765            79.05        117
# 6        Candelabro        11128.8       160            74.60         24
# 14         Heladera        25736.8       330            74.13         48
# 19  Lámpara De Mesa       82276.38      1112            72.72        176
# 20       Microondas       72562.89       912            79.18        135
# 28           Tablet       25856.57       374            71.38         58

# %% [markdown]
# ## 3.2 Análisis de Datos Exploratorio
# - *Boxplot* para ver dispersión de ingreso total por producto.
# - *Histograma* para ver la distribución del ingreso total por producto

# %%
import matplotlib.pyplot as plt

num_vals = resumen_prod['ingreso_total'].dropna()

plt.figure(figsize=(12,5))
plt.boxplot(num_vals,vert=False)
plt.title('Dispersión del Ingreso Total por Producto')
plt.xlabel('Ingreso Total')
plt.ylabel('Frecuencia')
plt.show()

# %%
color_green = "#0a662c"

plt.figure(figsize=(8, 6))
sns.histplot(num_vals, kde=True, color=color_green)
plt.title('Distribución del Ingreso Total por Producto')
plt.xlabel('Ingreso Total')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ## 3.3 Correlación
# Análisis de la relación entre precio promedio por producto y unidades vendidas por producto.

# %%
import matplotlib.pyplot as plt

x = resumen_prod['precio_promedio']
y = resumen_prod['unidades']

plt.figure(figsize=(7,5))
plt.scatter(x,y)
plt.title('Precio promedio contra Unidades (por Producto)')
plt.xlabel('Precio Promedio')
plt.ylabel('Unidades Vendidas')
plt.tight_layout()
plt.show()

# %%
# --------- Coeficiente de Correlación ---------

corr_val = resumen_prod[['precio_promedio','unidades']].corr().loc['precio_promedio','unidades']

print(f"Coeficiente de correlación (Pearson): {corr_val:.3f}")
# Interpretación simple:
if corr_val > 0.8:
    print("Interpretación: relación positiva clara (a mayor precio_promedio, se venden más unidades).")
elif corr_val > 0.2:
    print("Interpretación: relación positiva débil a moderada.")
elif corr_val < -0.8:
    print("Interpretación: relación negativa clara (a mayor precio_promedio, se venden menos unidades).")
elif corr_val < -0.3:
    print("Interpretación: relación negativa débil a moderada.")
else:
    print("Interpretación: relación muy débil o nula.")
# Out:
# Coeficiente de correlación (Pearson): 0.217
# Interpretación: relación positiva débil a moderada.

# %% [markdown]
# ## 4.1 Visualización con `matplotlib`

# %%
import matplotlib.pyplot as plt

df1 = resumen_prod.copy()
df_1 = df1.sort_values('ingreso_total', ascending=False)

color_magenta="#9f0161"
plt.figure(figsize=(12, 8))
barras = plt.bar(df_1['producto'], df_1['ingreso_total'], color = color_magenta)

plt.title('Ingresos Totales por Producto')
plt.xlabel('Producto')
plt.ylabel('Ingreso Total ($)')
plt.xticks(rotation=90)

for b in barras:
    h = b.get_height()
    x_c = b.get_x() + b.get_width()/2
    plt.text(x_c, h/2, f"${h:,.0f}", ha='center', va='center', color="white", rotation=90)

plt.tight_layout()
plt.show()

# %%
# Histograma: distribución de ingreso_total (por producto)

import matplotlib.pyplot as plt

serie = resumen_prod['ingreso_total']

plt.figure(figsize=(12, 6))
plt.hist(serie, bins=12, color= color_green)
plt.title('Distribución de ingreso_total (por producto)')
plt.xlabel('Ingreso total ($)')
plt.ylabel('Frecuencia')
plt.tight_layout()
plt.show()

# %%
# Grafico lineal cumsum de ingreso total ordenado
import matplotlib.pyplot as plt
import numpy as np

vals = resumen_prod['ingreso_total'].sort_values().values
acum = np.cumsum(vals)
color_teal="#006b6b"

plt.figure(figsize=(8, 4))
plt.plot(acum, color =color_teal)
plt.title('Tendencia Acumulada de Ingresos')
plt.xlabel('Índice Ordenado de Productos')
plt.ylabel('Ingreso Acumulado')
plt.tight_layout()
plt.show()

# %%
# Grafico de líneas que muestra los ingresos diarios y los ingresos acumulados

import matplotlib.pyplot as plt
import pandas as pd

# Convertir ventas_perform['fecha_venta'] a tipo datetime
ventas_perform['fecha_venta'] = pd.to_datetime(ventas_perform['fecha_venta'], errors='coerce')

#Agrupar ventas por fecha y sumar los ingresos por dia
ingreso_diario=ventas_perform.groupby('fecha_venta')['ingreso'].sum().sort_index()

#Calcular ingreso acumulado
ingresos_acum = ingreso_diario.cumsum()

# Graficar evolución de ventas por fecha
plt.figure(figsize=(12, 6))

# Línea 1: ingresos diarios
plt.plot(ingreso_diario, color=color_teal, label='Ingreso Diario')

# Línea 2: ingresos acumulados
plt.plot(ingresos_acum, color=color_indigo, label='Ingreso Acumulado', linewidth=2)

# Personalización del gráfico
plt.title('Evolución de Ingresos por fecha de venta')
plt.xlabel('Fecha de venta')
plt.ylabel('Ingresos ($)')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# Interpretación:
# Si aparecen saltos abruptos → picos de venta (promociones o campañas de marketing).

# %%
#Gráfico de barras para mosrar el ingreso total por producto

import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")      # estilo claro por defecto

# Barras ordenadas (Seaborn)
df = resumen_prod.sort_values('ingreso_total', ascending=False)
plt.figure(figsize=(12, 6))
ax = sns.barplot(data=df, x='producto', y='ingreso_total')
ax.set_title('Ingresos Totales por Producto (Seaborn)')
ax.set_xlabel('Producto')
ax.set_ylabel('Ingreso Total ($)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# gráfico de caja para mostrar el ingreso por registro, por categoria

plt.figure(figsize=(12, 6))
ax = sns.boxplot(data=ventas_perform, x='categoria', y='ingreso',color= color_teal)
ax.set_title('Ingreso por registro · Boxplot por categoría (Seaborn)')
ax.set_xlabel('Categoría')
ax.set_ylabel('Ingreso por registro ($)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4.3 Informe Final - Conclusiones del Proyecto
#
# -------------------------------------------------
# ## Preparación, limpieza e integración de datos
#
# El trabajo comenzó con la recopilación y exploración de los datasets de ventas, productos y marketing.
# El análisis de calidad permitió:
# - Detectar y corregir valores nulos y duplicados, garantizando la consistencia del dataset.
# - Normalizar los textos (por ejemplo, nombres de productos con acentos o mayúsculas inconsistentes).
# - Calcular y agregar nuevas columnas (ingreso_total = precio * cantidad) que resultan fundamentales para evaluar el rendimiento económico.
#
# Una vez limpios los datos, se filtaron los productos de alto rendimiento, eliminando los de baja venta o ingresos marginales.
#
# La integración (merge) entre ventas y marketing permitió obtener una visión completa del negocio, combinando métricas comerciales con información de campañas, esencial para futuras decisiones de inversión publicitaria.
#
# -------------------------------------------------
# ## Estadística descriptiva y análisis exploratorio (EDA)
#
# ### Medidas descriptivas:
#
# - Media del ingreso_total: ≈ $51.000.
#
# Representa el ingreso promedio por producto, pero está influenciada por algunos artículos con valores muy altos.
#
# - Mediana del ingreso_total: ≈ $48.000
#
# La media mayor que la mediana confirma una distribución asimétrica positiva, donde algunos productos excepcionales elevan el promedio general.
# - Desviación estándar: alrededor de $10.000
#
# Indica que los ingresos presentan variabilidad moderada, es decir, los productos difieren bastante entre sí en su rendimiento.
# - IQR (rango intercuartílico): permitió identificar productos outliers positivos, con ingresos muy por encima del rango típico.
#
# ### EDA (Análisis Exploratorio de Datos)
#
# Los gráficos complementaron la interpretación numérica:
#
# - El **histograma de ingreso_total** mostró una **distribución sesgada hacia la derecha**: la mayoría de los productos se concentran entre 40.000 y 55.000 pesos, mientras algunos pocos alcanzan más de 80.000.
#
# - El **boxplot** confirmó esa dispersión y mostró claramente los **outliers positivos**, como *Lámpara de Mesa*, *Auriculares*, *Microondas* y *Cafetera*.
#
# - Estas observaciones refuerzan la diferencia de peso de los productos: **no todos tienen el mismo peso económico**.
#
# - Los valores extremos reflejan casos de alto éxito comercial, no errores de carga.
# -------------------------------------------------
# ##Conclusiones y recomendaciones
#
# 1. **Los productos líderes** (Lámpara de Mesa, Auriculares, Microondas) generan una parte significativa del ingreso y deben potenciarse en estrategias de marketing.
# 2. **Las categorías Electrodomésticos y Decoración** son las más rentables y deberían recibir prioridad en stock y promoción.
# 3. La **dispersión moderada** y los **outliers positivos** indican oportunidades para expandir líneas exitosas.
# 4. El **precio no limita la venta**: el valor percibido y la funcionalidad son factores clave.
# 5. **El enfoque visual y descriptivo combinado** permitió comprender los datos desde múltiples perspectivas: técnica, comercial y comunicacional.
